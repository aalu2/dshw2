# %%
import pandas as pd
df=pd.read_csv('cancer.csv')
df.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# 4        201.9            0.08600             0.05943           0.01588
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
import seaborn as sns
sns.distplot(df['Area (mean)'], kde=False)
# Out:
# <ipython-input-7-c5446759e0b6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Area (mean)'], kde=False)
# <Axes: xlabel='Area (mean)'>

# %%
df['Perimeter (mean)'].max()
# Out:
# 188.5

# %%
sns.kdeplot(data=df['Area (mean)'], shade=True,)
# Out:
# <ipython-input-25-acb62086df64>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df['Area (mean)'], shade=True,)
# <Axes: xlabel='Area (mean)', ylabel='Density'>

# %%
sns.jointplot(x=df['Perimeter (mean)'], y=df['Area (mean)'], kind='kde')

# %%
df1=pd.read_csv('cancer_m.csv')
df1.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0    842302         M          17.99           10.38            122.80
# 1    842517         M          20.57           17.77            132.90
# 2  84300903         M          19.69           21.25            130.00
# 3  84348301         M          11.42           20.38             77.58
# 4  84358402         M          20.29           14.34            135.10
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0       1001.0            0.11840             0.27760            0.3001
# 1       1326.0            0.08474             0.07864            0.0869
# 2       1203.0            0.10960             0.15990            0.1974
# 3        386.1            0.14250             0.28390            0.2414
# 4       1297.0            0.10030             0.13280            0.1980
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
import seaborn as sns
sns.distplot(df1['Area (mean)'], kde=False)
# Out:
# <ipython-input-30-e3d81fcaf7e6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Area (mean)'], kde=False)
# <Axes: xlabel='Area (mean)'>

# %%
df2=pd.read_csv('cancer_b.csv')
df2.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# 4        201.9            0.08600             0.05943           0.01588
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
sns.distplot(a=df2['Area (mean)'], label='Malignant', kde=False)
sns.distplot(a=df1['Area (mean)'], label='Benign', kde=False)
sns.distplot(a=df['Area (mean)'], label='all', kde=False)
# Out:
# <ipython-input-33-a697259c5862>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df2['Area (mean)'], label='Malignant', kde=False)
# <ipython-input-33-a697259c5862>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.kdeplot(data=df2['Area (mean)'], shade=True)
sns.kdeplot(data=df1['Area (mean)'], shade=True)
sns.kdeplot(data=df['Area (mean)'], shade=True)
# Out:
# <ipython-input-38-4e20baa57196>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df2['Area (mean)'], shade=True)
# <ipython-input-38-4e20baa57196>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df1['Area (mean)'], shade=True)
# <ipython-input-38-4e20baa57196>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df['Area (mean)'], shade=True)
# <Axes: xlabel='Area (mean)', ylabel='Density'>

# %%
sns.distplot(a=df2['Radius (worst)'], label='Malignant', kde=False)
sns.distplot(a=df1['Radius (worst)'], label='Benign', kde=False)
sns.distplot(a=df['Radius (worst)'], label='all', kde=False)
# Out:
# <ipython-input-39-3c1c65293e00>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df2['Radius (worst)'], label='Malignant', kde=False)
# <ipython-input-39-3c1c65293e00>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.kdeplot(data=df2['Radius (worst)'], shade=True)
sns.kdeplot(data=df1['Radius (worst)'], shade=True)
sns.kdeplot(data=df['Radius (worst)'], shade=True)
# Out:
# <ipython-input-40-df1536038111>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df2['Radius (worst)'], shade=True)
# <ipython-input-40-df1536038111>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df1['Radius (worst)'], shade=True)
# <ipython-input-40-df1536038111>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df['Radius (worst)'], shade=True)
# <Axes: xlabel='Radius (worst)', ylabel='Density'>
